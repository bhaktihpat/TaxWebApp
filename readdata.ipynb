# %%
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important;}</style>"))

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv(r"C:\Users\Bhakt\Desktop\TaxWebApp\PropertyData_2020.txt", sep="|", encoding = 'ISO-8859-1', dtype='object')
df.head()

# %%
situs_address = df['Situs_Address'].str.split(expand = True)

Directions = ['N', 'E', 'W', 'S', 'North', 'East', 'West', 'South', 'NE', 'NW', 'SE', 'SW', 'NORTH', 'EAST', 'SOUTH', 'WEST']

St_type = ['RD', 'AVE', 'DR', 'CIR', 'LN', 'BLVD', 'ST', 'HWY', 'CT', 'PL', 'TR', 'PK', 'WAY', 'FWY', 'LOOP', 'PKWY', 'HIGHWAY', 'AVENUE', 'ROAD','FRWY', 'EXT', 'TRL', 'MEWS', 'IH']

A_unit = ['STE', 'BLDG', 'LOT', '#', 'Ste', 'UNIT', 'APT', 'Unit', 'STOP', 'SPC', 'TRLR', 'FL', 'Apt', 'RM', 'BOOTH', 'HNGR', 'REAR', 'SIDE', 'Rm', 'FC']

# leftover_counter = 0
# seven_worded_counter = 0
street_type = []
street_name = []
street_no = []
street_address = []
prefix = []
suffix = []

for row in situs_address.loc[:].values.tolist():
    
#####################################################################################################################################################################################################################################################################
# 7 worded addresses
##############################################################################################################################################################################################################################################
    if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None:
#         seven_worded_counter += 1


#   # Row[0] is numeric
#    if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True:
#         print(row)

#   #So there are no outputs from row[0] is not numeric so I don't need to expand this slicing command or write an array!
#    if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == False:
#        print(row)

    #Row[0] is numeric and Row[1] is directional
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions:
#         print(row)


    #Row[0] is numeric and row[1] is directional and row[2] in st_type
#       if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[2] in St_type):
#         print(row)


    #Accounted
    #Row[0] is numeric and row[1] is directional and row[2] = 'ROAD'
     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[2] == 'ROAD'):
#         print(row)

        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5] + ' ' + row[6])

        street_type.append(row[6])
        
        suffix.append(None)

    #Accounted
    #Row[0] is numeric and row[1] is directional and row[2] = 'LOOP'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[2] == 'LOOP'):
#         print(row)

        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(None)

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append('LOOP')
        
        suffix.append(row[5] + ' ' + row[6])

   #Accounted
    #Row[0] is numeric and row[1] is directional and row[2] not = 'ROAD'and row[2] not = 'LOOP' and row[2] in st_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[2] != 'ROAD') and (row[2] != 'LOOP') and (row[2] in St_type):
#         print(row)

        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(None)

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(row[3]+ ' ' + row[4] + ' ' + row[5] + ' ' + row[6])
    
    #Row[0] is numeric and row[1] is directional and row[3] in st_type 
#      if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type):
#         print(row)

      #Accounted
#      Row[0] is numeric and row[1] is directional and row[3] = LOOP
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] == 'LOOP'):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append('LOOP')
        
        suffix.append(row[5] + ' ' + row[6])

    #Accounted
    #Row[0] is numeric and row[1] is directional and row[3] in st_type and row[5] in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[5] in A_unit):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(row[5] + ' ' + row[6]) 
          
#      Row[0] is numeric and row[1] is directional and row[3] in st_type and row[5] = 'STOP'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[5] == 'STOP'):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(row[5] + ' ' + row[6])
     
    #Accounted
#     Row[0] is numeric and row[1] is directional and row[3] in st_type and row[5] not = 'STOP' and row[5] not in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[5] != 'STOP') and (row[5] not in A_unit):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4] + ' ' + row[5]  + ' ' + row[6])

    #Row[0] is numeric and row[1] is directional and row[4] in st_type 
#      if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[4] in St_type):
#         print(row)

    #Row[0] is numeric and row[1] is directional and row[4] in st_type and row[5] in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[4] in St_type) and (row[5] in A_unit):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3]  + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(row[5]  + ' ' + row[6])        

    #Row[0] is numeric and row[1] is directional and row[4] in st_type and row[5] not in A_unit
#      if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions  and (row[4] in St_type) and (row[5] not in A_unit):
#         print(row)

   #Row[0] is numeric and row[1] is directional and row[5] in st_type
#      if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions  and (row[5] in St_type):
#         print(row)
        
   #Row[0] is numeric and row[1] is directional and row[6] in st_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions  and (row[6] in St_type):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5] + ' ' + row[6])

        street_type.append(row[6])
        
        suffix.append(None)
        
   #Row[0] is numeric and row[1] is directional and row[4] == 'P'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions  and (row[4] == 'P'):
#         print(row)

        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append('P')
        
        suffix.append(row[5] + ' ' + row[6])
        
   #Row[0] is numeric and row[1] is directional and row[2] == 'IH'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] in Directions  and (row[2] == 'IH'):
#         print(row)

        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(None)
        
        suffix.append(row[4] + ' ' + row[5] + ' ' + row[6])       
##############################################################################

    #Row[0] is numeric and Row[1] is not directional    
#    if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions:
#        print(row)  


    # My hunch is that not in St_type will apply to all rows, to proof check that I haven't missed anything I will go through individially and check each row in St_type.
    #Row[1] in St_stype
#      Accounted
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[1] in St_type):
#         print(row)

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(None)
        
        suffix.append(row[5] + ' ' + row[6])


#      Accounted
#      row[1]= hwy
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[1] == 'HWY'):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append('HWY')
        
        suffix.append(row[5] + ' ' + row[6])
        

#     Accounted
#    #Row[2] in St_type row[3] in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[2] in St_type) and (row[3] in A_unit):
#         print(row) 

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])
 
        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(row[3] + ' ' + row[4] + ' ' + row[5] + ' ' + row[6])
        
#     Accounted
#     #Row[2] in St_typerow[3] not in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[2] in St_type) and (row[3] not in A_unit):
#         print(row) 

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])
 
        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(row[5] + ' ' + row[6])


#   Accounted
    #Row[3] in St_type row[4] in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[3] in St_type) and (row[4] in A_unit):
#         print(row)

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4] + ' ' + row[5] + ' ' + row[6]) 
        
    #   Accounted
    #Row[3] in St_type row[4] not in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[3] in St_type) and (row[4] not in A_unit):
#         print(row)

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[5] + ' ' + row[6]) 

#   Accounted
    #Row[4] in St_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[4] in St_type):
#         print(row)

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(row[5] + ' ' + row[6])


    #Row[5] in St_type has no addresses    
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[5] in St_type):
#         print(row)


#    Accounted
     #Row[6] in St_type   
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[6] in St_type):
#         print(row)

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5] + ' ' + row[6])

        street_type.append('ST')
        
        suffix.append(None)
                
    #All rows not in st_type
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[1] not in St_type) and (row[2] not in St_type) and (row[3] not in St_type) and (row[4] not in St_type) and (row[5] not in St_type) and (row[6] not in St_type):
#         print(row)

     # 7 worded addresses
#     elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is not None and row[7] is None:
#         print(row)
#         leftover_counter += 1


#######################################################################################################################################################################################################################################
    #6 worded addresses  
#########################################################################################################################################################################################################################################    
    if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None:
#         #print(row)
#         six_worded_counter += 1

    #Row[0] is numeric    
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True:
#         print(row)
    
    #Row[0] is numeric and Row[1] in directions
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions:
#         print(row)

#Accounted
    #Row[0] is numeric and Row[1] in directions and row[2] == 'ROAD'
     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[2] == 'ROAD'):
#         print(row) 

        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4]  + ' ' + row[5])

        street_type.append(None)
        
        suffix.append(None)

    #Accounted
    #Row[0] is numeric and Row[1] in directions and row[2] in st type and row[2] !='ROAD'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[2] in St_type) and (row[2] != 'ROAD'):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(None)

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[2])
        
        suffix.append(row[4]  + ' ' + row[5])

#Accounted
    #Row[0] is numeric and Row[1] in directions and row[3] in st type and row[4] in a_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] in A_unit):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4]  + ' ' + row[5])


#     #Row[0] is numeric and Row[1] in directions and row[3] in st type and row[4] not in a_unit and row[4] is numeric
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (str(row[4]).isnumeric() == True):
#         print(row)

    #Accounted    
    #Row[0] is numeric and Row[1] in directions and row[3] in st type and row[4] not in a_unit and row[4] is numeric and row[5] is directional 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (str(row[4]).isnumeric() == True) and (row[5] in Directions):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(None)
#Accounted
    #Row[0] is numeric and Row[1] in directions and row[3] in st type and row[4] not in a_unit and row[4] is numeric  and row[5] == STE
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (str(row[4]).isnumeric() == True) and (row[5] == 'STE'):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append('STE')
#Accounted
    #Row[0] is numeric and Row[1] in directions and row[3] in st type and row[4] not in a_unit and row[4] is numeric  and row[5] == CIR
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (str(row[4]).isnumeric() == True) and (row[5] == 'CIR'):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(None)
#Accounted
    #Row[0] is numeric and Row[1] in directions and row[3] in st type and row[4] not in a_unit and row[4] is numeric  and row[5] == HWY
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (str(row[4]).isnumeric() == True) and (row[5] == 'HWY'):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(None)
#Accounted
    #Row[0] is numeric and Row[1] in directions and row[3] in st type and row[4] not in a_unit and row[4] is numeric  and row[5] == #105
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (str(row[4]).isnumeric() == True) and (row[5] == '#105'):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append('#105')
#Accounted        
     #Row[0] is numeric and Row[1] in directions and row[3] in st type and row[4] not in a_unit and row[4] is numeric  and row[5] == E/E33
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (str(row[4]).isnumeric() == True) and (row[5] == 'E/E33'):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(None)
#Accounted
#     #Row[0] is numeric and Row[1] in directions and row[3] in st type and row[4] not in a_unit and row[4] is not numeric
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (str(row[4]).isnumeric() == False):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4] + ' ' + row[5])
#Accounted
    #Row[0] is numeric and Row[1] in directions and row[4] in st type and row[5] in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[4] in St_type) and (row[5] in A_unit):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(row[5])
    #Row[0] is numeric and Row[1] in directions and row[4] in st type and row[5] not in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[4] in St_type) and (row[5] not in A_unit):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(None)
#Accounted
    #Row[0] is numeric and Row[1] in directions and row[5] in st type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[5] in St_type):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5])

        street_type.append(row[5])
        
        suffix.append(None)
        
    #Row[0] is numeric and Row[1] in directions and row[3] is numeric
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (str(row[3]).isnumeric() == True):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(None)
        
        suffix.append(row[4] + ' ' + row[5])       

    #Row[0] is numeric and Row[1] not in directions
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and row[1] not in Directions:
#         print(row)
#Accounted
    #Row[0] is numeric and Row[1] not in directions and Row[2] in St_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[2] in St_type):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[2])
        
        suffix.append(row[4]  + ' ' + row[5])
#Accounted    
    #Row[0] is numeric and Row[1] not in directions and Row[3] in St_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[3] in St_type):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4]  + ' ' + row[5])        
        
     #Row[0] is numeric and Row[1] not in directions and Row[4] in St_type
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[4] in St_type):
#         print(row)
#Accounted
     #Row[0] is numeric and Row[1] not in directions and Row[4] in St_type and row[5] in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[4] in St_type) and (row[5] in A_unit):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(row[5])
#Accounted
     #Row[0] is numeric and Row[1] not in directions and Row[4] in St_type and row[5] in Directions
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[4] in St_type) and (row[5] in Directions):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(None)
#Accounted        
     #Row[0] is numeric and Row[1] not in directions and Row[4] in St_type and row[5] not in A_unit and row[5] not in Directions
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[4] in St_type) and (row[5] not in A_unit) and (row[5] not in Directions):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(row[5])
#Accounted
     #Row[0] is numeric and Row[1] not in directions and row[5] in St_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[5] in St_type):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5])

        street_type.append(row[5])
        
        suffix.append(None)  
 
     #Row[0] is numeric and Row[1] not in directions and row[4] in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[4] in A_unit):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4] + ' ' + row[5])  
        
#accounted        
     #Row[0] is numeric and Row[1] not in directions and row[1] in st_type and row[1] not= 'ST' and row[3] not in st_type and row[1] not= 'ROAD'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[1] in St_type) and (row[1] != 'ST') and (row[3] not in St_type) and (row[1] != 'ROAD'):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[1])
        
        suffix.append(row[4] + ' ' + row[5])        
#Accounted        
     #Row[0] is numeric and Row[1] not in directions and row[1] in st_type and row[1] not= 'ST' and row[3] not in st_type and row[1] = 'ROAD'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[1] in St_type) and (row[1] != 'ST') and (row[3] not in St_type) and (row[1] == 'ROAD'):
#         print(row)        
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4] + ' ' + row[5])

        street_type.append(row[5])
        
        suffix.append(None)
    
##########################
    #Row[0] is not numeric, outputs 14. 12 of which are directional the last two start with heritage and bus  
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == False:
#         print(row)

    #Accounted
    #Row[0] is not numeric and row[0] is directional
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == False and (row[0] in Directions):
#         print(row)
        
        street_no.append(None)

        prefix.append(row[0])

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4]  + ' ' + row[5])

        street_type.append(row[5])
        
        suffix.append(None)

    #Accounted
    #Row[0] is not numeric and row[0] not directional
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions):
#         print(row)
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4]  + ' ' + row[5])

        street_type.append(row[5])
        
        suffix.append(None)

    #Row[0] is not numeric and (row[0] not in Directions) and row[5] not in St_type
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions) and (row[5] not in St_type):
#         print(row)
        
    #6 worded addresses    
#     elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is not None and row[6] is None:
#         print(row)
#         leftover_counter += 1

########################################################################################################################################################################################################################################
    #5 worded addresses  
########################################################################################################################################################################################################################################    
    if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None:
# #         print(row)
#           five_worded_counter += 1
        
    #Row[0] is numeric    
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True:
#         print(row)

    #Row[0] is numeric and row[1] in directions  
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions:
#         print(row)

    #Row[0] is numeric and row[1] in directions and row[2] in St_type 
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[2] in St_type):
#         print(row)
#Accounted
    #Row[0] is numeric and row[1] in directions and row[2] in St_type and row[3] in A_unit
     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[2] in St_type) and (row[3] in A_unit):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(row[3] + ' ' + row[4])  
        
#Accounted        
    #Row[0] is numeric and row[1] in directions and row[2] in St_type and row[3] not in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[2] in St_type) and (row[3] not in A_unit):
#         print(row)        
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[2])
        
        suffix.append(None) 

    #Row[0] is numeric and row[1] in directions and row[3] in St_type 
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type):
#         print(row)
#Accounted
    #Row[0] is numeric and row[1] in directions and row[3] in St_type and row[4] in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] in A_unit):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4])  
        
#Accounted
    #Row[0] is numeric and row[1] in directions and row[3] in St_type and row[4] is numeric 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (str(row[4]).isnumeric() == True):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(None)
        
#Accounted
    #Row[0] is numeric and row[1] in directions and row[3] in St_type and row[4] is directional 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] in Directions):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(None)
        
#Accounted
    #Row[0] is numeric and row[1] in directions and row[3] in St_type and row[4] = 'CIR'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and row[4] == 'CIR':
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(None)
        
#Accounted
    #Row[0] is numeric and row[1] in directions and row[3] in St_type and row[4] = 'RD'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and row[4] == 'RD':
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(None)
        
#Accounted
    #Row[0] is numeric and row[1] in directions and row[3] in St_type and row[4] = 'EXT'
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and row[4] == 'EXT':
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(None)
        
#Accounted 
    #Row[0] is numeric and row[1] in directions and row[3] in St_type and row[4] not in A_unit and row [4] is not numeric and row[4] is not directional and row[4] != 'CIR' and row[4] != 'RD' and row[4] != 'EXT' 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (str(row[4]).isnumeric() == False) and (row[4] not in Directions)  and row[4] != 'CIR' and row[4] != 'RD' and row[4] != 'EXT' :
#         print(row) 
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4])        

#Accounted
    #Row[0] is numeric and row[1] in directions and row[4] in St_type 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[4] in St_type):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(None)
        
    #Row[0] is numeric and row[1] in directions and row[4] == P 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (row[4] == 'P'):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(None)
        
        suffix.append(None)        
        
    #Row[0] is numeric and row[1] in directions and row[4]is numeric 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in Directions and (str(row[4]).isnumeric() == True):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(None)
        
        suffix.append(None)        
###
    #Row[0] is numeric and row[1] not in directions   
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions:
#         print(row) 
        
    #Row[0] is numeric and row[1] not in directions and row[2] in st_type   
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[2] in St_type):
#         print(row)

#Accounted        
    #Row[0] is numeric and row[1] not in directions and row[2] in st_type and row[3] in A_unit  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[2] in St_type) and (row[3] in A_unit):
#         print(row)      
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(row[3] + ' ' + row[4])  
        
#Accounted
    #Row[0] is numeric and row[1] not in directions and row[2] in st_type and row[3] not in A_unit and row[4] is directional 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[2] in St_type) and (row[3] not in A_unit) and (row[4] in Directions):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[2])
        
        suffix.append(None) 
        
#Accounted
#Row[0] is numeric and row[1] not in directions and row[2] in st_type and row[3] not in A_unit and row[4] not directional 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[2] in St_type) and (row[3] not in A_unit) and (row[4] not in Directions):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[2])
        
        suffix.append(row[4])        
        
    #Row[0] is numeric and row[1] not in directions and row[3] in st_type   
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[3] in St_type):
#         print(row)
#Accounted
#     #Row[0] is numeric and row[1] not in directions and row[3] in st_type and row[4] in A_unit  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[3] in St_type) and (row[4] in A_unit):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4])         

    #Row[0] is numeric and row[1] not in directions and row[3] in st_type and row[4] not in A_unit  
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[3] in St_type) and (row[4] not in A_unit):
#         print(row)
#Accounted
    #Row[0] is numeric and row[1] not in directions and row[3] in st_type and row[4] not in A_unit and row[4] is directional 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (row[4] in Directions):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(None) 
#Accounted
    #Row[0] is numeric and row[1] not in directions and row[3] in st_type and row[4] not in A_unit and row[4] is directional and row[4] is numeric
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (row[4] not in Directions) and (str(row[4]).isnumeric() == True):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(None)    

    #Row[0] is numeric and row[1] not in directions and row[3] in st_type and row[4] not in A_unit and row[4] not directional amd row[4] is not numeric 
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[3] in St_type) and (row[4] not in A_unit) and (row[4] not in Directions) and (str(row[0]).isnumeric() == False):
#         print(row)

    #Row[0] is numeric and row[1] not in directions and row[3] in st_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[3] in St_type):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(row[4])

#Accounted
    #Row[0] is numeric and row[1] not in directions and row[4] in st_type   
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] not in Directions and (row[4] in St_type):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(None) 
           
    #Row[0] is numeric and row[1] in st_type   
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == True and row[1] in St_type:
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(None)
        
        suffix.append(None)     
        
     #Row[0] is numeric and row[4] in directions  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and (row[4] in Directions):
#         print(row)    

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(None)
        
        suffix.append(None)                
            
     #Row[0] is numeric and row[3] in A_unit  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and (row[3] in A_unit):
#         print(row)    

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(None)
        
        suffix.append(row[3] + ' ' + row[4])           
        
      #Row[0] is numeric and row[2] == AIRPORT  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and (row[2] == 'AIRPORT'):
#         print(row)    

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(None)
        
        suffix.append(row[4])       
        
      #Row[0] is numeric and row[4] == R  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and (row[4] == 'R'):
#         print(row)    

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(None)
        
        suffix.append(None)        
        
      #Row[0] is numeric and row[4] == MALL  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and (row[4] == 'MALL'):
#         print(row)    

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(None)
        
        suffix.append(None)      
        
      #Row[0] is numeric and row[4] == CENTER  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and (row[4] == 'CENTER'):
#         print(row)    

        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(None)
        
        suffix.append(None)        
        
##################################################################    
    #Row[0] is not numeric    
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == False:
#         print(row)
#Accounted
    #Row[0] is not numeric and row[4] in st_type   
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == False and (row[4] in St_type):
#         print(row)
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[4])
        
        suffix.append(None)         
        
    #Row[0] is not numeric and row[4] not in st_type   
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == False and (row[4] not in St_type):
#         print(row)  
#Accounted        
    #Row[0] is not numeric and row[4] not in st_type and row[3] in A_unit 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == False and row[4] not in St_type and (row[3] in A_unit):
#         print(row) 
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0] + ' ' + row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(row[3] + ' ' + row[4])
        
#Accounted        
    #Row[0] is not numeric and row[4] not in st_type and row[3] not in A_unit 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None and str(row[0]).isnumeric() == False and row[4] not in St_type and (row[3] not in A_unit):
#         print(row)
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0] + ' ' + row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3] + ' ' + row[4])

        street_type.append(row[3])
        
        suffix.append(None)   
        
     
        
#     elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is not None and row[5] is None:
#         print(row)
#         leftover_counter += 1  

################################################################################################################################################################################################################################
# 4 worded addresses
###################################################################################################################################   
    if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None:
#         print(row)
#           four_worded_counter += 1
    
    #Row[0] is numeric    
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True:
#         print(row)

    #Row[0] is numeric and row[1] in Directions   
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] in Directions):
#         print(row)
#Accounted
    #Row[0] is numeric and row[1] in Directions and row[2] in st_type 
    if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] in Directions) and (row[2] in St_type):
#         print(row)
        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[2])
        
        suffix.append(None)        
#Accounted
    #Row[0] is numeric and row[1] in Directions and row[3] in st_type 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] in Directions) and (row[3] in St_type):
#         print(row)

        street_no.append(row[0])

        prefix.append(row[1])

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(None) 
           
   #Row[0] is numeric and row[1] not in Directions   
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions):
#         print(row)
#Accounted
   #Row[0] is numeric and row[1] not in Directions and row[3] in St_type  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[3] in St_type):
# #         print(row)
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(None)

   #Row[0] is numeric and row[1] not in Directions and row[2] in St_type  
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[2] in St_type):
#         print(row)
#Accounted
   #Row[0] is numeric and row[1] not in Directions and row[2] in St_type and row[3] in Directions
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[2] in St_type) and (row[3] in Directions):
# #         print(row)    
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)         
#Accounted
#    #Row[0] is numeric and row[1] not in Directions and row[2] in St_type and row[3] in A_unit
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[2] in St_type) and (row[3] in A_unit):
# #         print(row)    
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(row[3])  

#Accounted
   #Row[0] is numeric and row[1] not in Directions and row[2] in St_type and row[3] is numeric
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[2] in St_type) and (str(row[3]).isnumeric() == True):
# #         print(row)    
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[2])
        
        suffix.append(None)
#Accounted
   #Row[0] is numeric and row[1] not in Directions and row[2] in St_type and row[3] is not numeric, not directional, not in A_unit and not in st_type (row two is actually a st name so do row 3 in st type forst to deal with those addreses)
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[2] in St_type) and (str(row[3]).isnumeric() == False) and (row[3] not in Directions) and (row[3] not in A_unit) and (row[3] not in St_type):
# #         print(row)
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(row[3])  
#Accounted           
   #Row[0] is numeric and row[1] not in Directions and row[1] in St_type  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True and (row[1] not in Directions) and (row[1] in St_type):
# #         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(None)    
       
    #Row[0] is not numeric    
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False:
#         print(row)
        
#     #Row[0] is not numeric and row[0] in Directions   
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] in Directions):
#         print(row)
#Accounted
    #Row[0] is not numeric and row[0] in Directions and row[3] in St_type  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] in Directions) and (row[3] in St_type):
# #         print(row)
        
        street_no.append(None)

        prefix.append(row[0])

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(None)

#Accounted
    #Row[0] is not numeric and row[0] in Directions and row[2] in St_type  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] in Directions) and (row[2] in St_type):
# #         print(row)
        
        street_no.append(None)

        prefix.append(row[0])

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[2])
        
        suffix.append(None) 
#ACCOUNTED
    #Row[0] is not numeric and row[0] in Directions and row[1] in St_type  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] in Directions) and (row[1] in St_type):
# #         print(row)
        
        street_no.append(None)

        prefix.append(row[0])

        street_name.append(None)

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[1])
        
        suffix.append(None)  
        
   #Row[0] is not numeric and row[0] not in Directions   
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions):
#         print(row)        
#Accounted
   #Row[0] is not numeric and row[0] not in Directions and row[3] in st_type  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions) and (row[3] in St_type):
# #         print(row) 
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[3])
        
        suffix.append(None)     
#Accounted        
   #Row[0] is not numeric and row[0] not in Directions and row[2] in st_type  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions) and (row[2] in St_type):
# #         print(row)     
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0]+ ' ' + row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[2])
        
        suffix.append(None)      
        
   #Row[0] is not numeric and row[0] not in Directions and row[1] in st_type  
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions) and (row[1] in St_type):
#         print(row) 
#ACCOUNTED        
   #Row[0] is not numeric and row[0] not in Directions and row[1] in st_type and row[2] in A_unit 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions) and (row[1] in St_type) and (row[2] in A_unit):
# #         print(row)         
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0])

        street_address.append(row[0]+ ' ' + row[1])

        street_type.append(row[1])
        
        suffix.append(row[2] + ' ' + row[3])

   #Row[0] is not numeric and row[0] not in Directions and row[1] in st_type and row[2] not in A_unit 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions) and (row[1] in St_type) and (row[2] not in A_unit):
# #         print(row)
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(row[1])
        
        suffix.append(None)     
        
   #Row[0] is numeric  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and str(row[0]).isnumeric() == True:
# #         print(row)
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(None)
        
        suffix.append(None)    
        
   #Row[3] is directional  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and row[3] in Directions:
# #         print(row)
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(None)
        
        suffix.append(None)       
        
    #Row[0] == 'HWY'  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and row[0] == 'HWY':
# #         print(row)
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(None)
        
        suffix.append(None)      
        
   #Row[3] == 'R'  
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None and row[3] == 'R':
# #         print(row)
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_address.append(row[0] + ' ' + row[1] + ' ' + row[2] + ' ' + row[3])

        street_type.append(None)
        
        suffix.append(None)           
        
#     elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is not None and row[4] is None:
#         print(row)
#         leftover_counter += 1      
###################################################################################################################################################################################################################################

####################################################################################################################################################################################################################################
    #3 worded addresses 
#######################################################################################################################################################################################################################################
    if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None:
# # #         print(row)
#           three_worded_counter += 1

    #Row[0] is numeric    
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == True:
#         print(row)
#Accounted
    #Row[0] is numeric and row[2] in St_type   
     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == True and (row[2] in St_type):
# #         print(row)
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)   
        
#Accounted
    #Row[0] is numeric and row[1] in St_type   
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == True and (row[1] in St_type):
# #         print(row)
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[1])
        
        suffix.append(None) 
        
    #Row[0] is numeric and row[2] is numeric   
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == True and (str(row[2]).isnumeric() == True):
#         print(row)
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[1])
        
        suffix.append(None)        
        
    #Row[0] is numeric    
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == True:
#         print(row)
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(None)
        
        suffix.append(None)        
        
    #Row[0] is not numeric    
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == False:
#         print(row)

    #Row[0] is not numeric and row[0] in Directions  
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == False and (row[0] in Directions):
#         print(row)
#Accounted
    #Row[0] is not numeric and row[0] in Directions and row[2] in St_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == False and (row[0] in Directions) and (row[2] in St_type):
# #         print(row)        
        street_no.append(None)

        prefix.append(row[0])

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)  
#Accounted
    #Row[0] is not numeric and row[0] in Directions and row[1] in St_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == False and (row[0] in Directions) and (row[1] in St_type):
# #         print(row)        
        street_no.append(None)

        prefix.append(row[0])

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[1])
        
        suffix.append(None)          
        
    #Row[0] is not numeric and row[0] not in Directions  
#     if row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions):
#         print(row)      
#Accounted
    #Row[0] is not numeric and row[0] not in Directions and row[2] in st type 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions) and (row[2] in St_type):
# #         print(row)  
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)       
#Accounted
    #Row[0] is not numeric and row[0] not in Directions and row[1] in st type 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == False and (row[0] not in Directions) and (row[1] in St_type):
# #         print(row)  
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[1])
        
        suffix.append(None) 


    #Row[0] is not numeric and row[2] is numeric 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == False and (str(row[2]).isnumeric() == True):
#          print(row)  
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[1])
        
        suffix.append(None)
        
        
        #row[0] in st_type
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[0] in St_type:
#          print(row)  
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[0])
        
        suffix.append(None)   
        
    #Row[0] is not numeric and row[2] is DIRECTIONAL 
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and str(row[0]).isnumeric() == False and (row[2] in Directions):
#          print(row)  
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[1])
        
        suffix.append(None)        

#   row[2] = TERR
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'TERR':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = WLK
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'WLK':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = LAYNE
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'LAYNE':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = GREEN
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'GREEN':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(None)
        
        suffix.append(None)

#   row[2] = VIEW
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'VIEW':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1] + ' ' + row[2])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(None)
        
        suffix.append(None)

#   row[2] = CONCOURSE
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'CONCOURSE':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = MUNICIPAL
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'MUNICIPAL':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = MALL
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'MALL':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = STATION
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'STATION':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = BRANCH
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'BRANCH':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = VISTA
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'VISTA':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = LANCE
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'LANCE':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = SQ
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'SQ':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = BEND
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'BEND':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = SPRINGS
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'SPRINGS':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = ROW
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'ROW':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = HILL
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'HILL':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)
        
#   row[2] = RUN
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'RUN':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = CREST
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'CREST':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = PT
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'PT':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = HOLLOW
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'HOLLOW':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = ROSS
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'ROSS':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = RDG
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'RDG':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = CARDINAL
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'CARDINAL':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = OAKS
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'OAKS':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = MILLS
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'MILLS':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = LEVEE
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'LEVEE':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = ARLINGTON
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'ARLINGTON':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = PLZ
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'PLZ':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = LAKE
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'LAKE':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = OVAL
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'OVAL':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = PARK
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'PARK':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = AIRPORT
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'AIRPORT':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = CRESCENT
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'CRESCENT':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)

#   row[2] = BRITTON
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'BRITTON':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)
#   row[2] = BRITON
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'BRITON':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)      
        
#   row[2] = TRL
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'TRL':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)
        
#   row[2] = CENTER
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'CENTER':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)        
        
#   row[2] = EXPWY
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'EXPWY':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)       

#   row[2] = DR&ROSEDAL
    elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None and row[2] == 'DR&ROSEDAL':
#          print(row)  
        
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1] + ' ' + row[2])

        street_type.append(row[2])
        
        suffix.append(None)        
        
#     elif row[0] is not None and row[1] is not None and row[2] is not None and row[3] is None:
#         print(row)
#         leftover_counter += 1

##############################################################################################################################################################################
    #2 worded addresses    
################################################################################################################################################################    
    
    if row[0] is not None and row[1] is not None and row[2]is None:
#         print(row)
          two_worded_counter += 1
    
    #row[0] and row[1] == Current address
#     if row[0] is not None and row[1] is not None and row[2]is None and (row[0] == 'Current') and (row[1] == 'Address'):
#         print(row)
#Accounted
    #Row[0] is numeric row[0] and row[1] not = Current address and row[1] in st type  
    if row[0] is not None and row[1] is not None and row[2] is None and str(row[0]).isnumeric() == True and (row[0] != 'Current') and (row[1] != 'Address') and (row[1] in St_type):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(None)

        street_address.append(row[0]+ ' ' + row[1])

        street_type.append(row[1])
        
        suffix.append(None) 

    #Row[0] is numeric row[0] and row[1] not = Current address   
    if row[0] is not None and row[1] is not None and row[2] is None and str(row[0]).isnumeric() == True and (row[0] != 'Current') and (row[1] != 'Address'):
#         print(row)
        street_no.append(row[0])

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1])

        street_type.append(None)
        
        suffix.append(None)  
        
    #Row[0] is not numeric row[0] and row[1] not = Current address  
#     if row[0] is not None and row[1] is not None and row[2] is None and str(row[0]).isnumeric() == False and (row[0] != 'Current') and (row[1] != 'Address'):
#         print(row)
        
    #Row[0] is not numeric row[0] and row[1] not = Current address and row[1] in st type  
    elif row[0] is not None and row[1] is not None and row[2] is None and str(row[0]).isnumeric() == False and (row[0] != 'Current') and (row[1] != 'Address') and (row[1] in St_type):
#         print(row)  
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0])

        street_address.append(row[0]+ ' ' + row[1])

        street_type.append(row[1])
        
        suffix.append(None) 
#Accounted
    #Row[0] is not numeric row[0] and row[1] not = Current address and row[0] in st type  
    elif row[0] is not None and row[1] is not None and row[2] is None and str(row[0]).isnumeric() == False and (row[0] != 'Current') and (row[1] != 'Address') and (row[0] in St_type):
#         print(row) 
        
        street_no.append(None)

        prefix.append(None)

        street_name.append(row[1])

        street_address.append(row[0]+ ' ' + row[1])

        street_type.append(row[0])
        
        suffix.append(None)
        
    #Row[0] is not numeric row[0] and row[1] not = Current address  
    elif row[0] is not None and row[1] is not None and row[2] is None and str(row[0]).isnumeric() == False and (row[0] != 'Current') and (row[1] != 'Address'):
#         print(row)  

        street_no.append(None)

        prefix.append(None)

        street_name.append(row[0]+ ' ' + row[1])

        street_address.append(row[0]+ ' ' + row[1])

        street_type.append(None)
        
        suffix.append(None)         

#     elif row[0] is not None and row[1] is not None and row[2]is None:
#         print(row)
#         leftover_counter += 1

    else:
        street_no.append(None)
        prefix.append(None)
        street_name.append(None)
        street_address.append(None)
        street_type.append(None)
        suffix.append(None)

# %%
df['Street_no'] = pd.Series(street_no)

df['Prefix'] = pd.Series(prefix)

df['Street_name'] = pd.Series(street_name)

df['Street_address'] = pd.Series(street_address)

df['Street_type'] = pd.Series(street_type)

df['Suffix'] = pd.Series(suffix)

df['Prefix'] = df['Prefix'].str.rstrip()

df['Street_type'] = df['Street_type'].str.rstrip()

df.head(100)

# %%
try:
    
    env.overwriteOutput = True

    env.workspace = r'C:\Users\Bhakt\Desktop\TaxWebApp\TADLayers\TADLayers.gdb'

    fcname = 'PropertyData'

    fclass = os.path.join(arcpy.env.workspace,fcname)



    # fields from the PropertyData table

    fields = ['RP','Appraisal_Year','Account_Num','Record_Type','Sequence_No','PIDN',

              'Owner_Name','Owner_Address','Owner_CityState','Owner_Zip','Owner_Zip4',

              'Owner_CRRT','Situs_Address','Property_Class','TAD_Map','MAPSCO','Exemption_Code',

              'State_Use_Code','LegalDescription','Notice_Date','County','City','School',

              'Num_Special_Dist','Spec1','Spec2','Spec3','Spec4','Spec5','Deed_Date','Deed_Book',

              'Deed_Page','Land_Value','Improvement_Value','Total_Value','Garage_Capacity',

              'Num_Bedrooms','Num_Bathrooms','Year_Built','Living_Area','Swimming_Pool_Ind',

              'ARB_Indicator','Ag_Code','Land_Acres','Land_SqFt','Ag_Acres','Ag_Value',

              'Central_Heat_Ind','Central_Air_Ind','Structure_Count','From_Accts','Appraisal_Date',

              'Appraised_Value','GIS_Link','Instrument_No','Overlap_Flag','PropertyTax',

              'CityName', 'CountyName', 'Street_No', 'Prefix', 'Street_Name', 'Street_Address', 'Street_Type', 'Suffix']



    

    # fields from the pandas dataframe

    inputs = df.loc[:,['RP','Appraisal_Year','Account_Num','Record_Type','Sequence_No','PIDN',

              'Owner_Name','Owner_Address','Owner_CityState','Owner_Zip','Owner_Zip4',

              'Owner_CRRT','Situs_Address','Property_Class','TAD_Map','MAPSCO','Exemption_Code',

              'State_Use_Code','LegalDescription','Notice_Date','County','City','School',

              'Num_Special_Dist','Spec1','Spec2','Spec3','Spec4','Spec5','Deed_Date','Deed_Book',

              'Deed_Page','Land_Value','Improvement_Value','Total_Value','Garage_Capacity',

              'Num_Bedrooms','Num_Bathrooms','Year_Built','Living_Area','Swimming_Pool_Ind',

              'ARB_Indicator','Ag_Code','Land_Acres','Land_SqFt','Ag_Acres','Ag_Value',

              'Central_Heat_Ind','Central_Air_Ind','Structure_Count','From_Accts','Appraisal_Date',

              'Appraised_Value','GIS_Link','Instrument_No','Overlap_Flag','Property_Tax',

              'CityNames', 'Countyname', 'Street_no', 'Prefix', 'Street_name', 'Street_address', 'Street_type', 'Suffix']].values.tolist()

    

    # create an InsertCursor object to insert rows

    InsertCursor = arcpy.da.InsertCursor(fclass,fields)



    for row in inputs:

        InsertCursor.insertRow(row)



    del InsertCursor



except Exception as ex:

    print(str(ex))
